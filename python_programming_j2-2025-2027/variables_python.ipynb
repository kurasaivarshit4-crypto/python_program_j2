# %% [markdown]
# # variables in python
# 1. variables is memory allocation to a value
# 2. example are `name="varshit"``age16

# %%
name="varshit"
age=16
salary=5000
print(name)
print(age)
print(salary)
# Out:
# varshit
# 16
# 5000

# %% [markdown]
# # key points to definde variables
# 1. variables does not start with digit
# 2. variables does not allow special characters
# 3. do not use keywords as a variables

# %%
1 name="varshit'
print(1name)
# Out:
#   Cell In[2], line 1
#     1 name="varshit'
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
f_name"varshit"
print(f_name)
# Out:
#   Cell In[3], line 1
#     f_name"varshit"
#           ^
# SyntaxError: invalid syntax

# %%
for="varshit"
print(for)
# Out:
#   Cell In[4], line 1
#     for="varshit"
#        ^
# SyntaxError: invalid syntax

# %%
for1="varshit"
print=(for1)

# %% [markdown]
# for1="varshit"
# print=(for1)

# %%
data="120"
print(data)
print(type(data))
# Out:
# 120
# <class 'str'>
